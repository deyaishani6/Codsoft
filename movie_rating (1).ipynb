# %%
## Task 2: Movie rating Prediction with Python


import pandas as pd

# %% [markdown]
# #### loading data rating

# %%
rating=pd.read_csv("C:/Users/Aishani/Downloads/ratings.dat",sep = '::', engine='python')

# %%
rating
# Out:
#             1  1193  5  978300760
# 0           1   661  3  978302109
# 1           1   914  3  978301968
# 2           1  3408  4  978300275
# 3           1  2355  5  978824291
# 4           1  1197  3  978302268
# ...       ...   ... ..        ...
# 1000203  6040  1091  1  956716541
# 1000204  6040  1094  5  956704887
# 1000205  6040   562  5  956704746
# 1000206  6040  1096  4  956715648
# 1000207  6040  1097  4  956715569
#
# [1000208 rows x 4 columns]

# %%
#loading data user
user=pd.read_csv("C:/Users/Aishani/Downloads/users.dat",sep = '::', engine='python')

# %%
user
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# ...    ... ..  ...  ..    ...
# 6034  6036  F   25  15  32603
# 6035  6037  F   45   1  76006
# 6036  6038  F   56   1  14706
# 6037  6039  F   45   0  01060
# 6038  6040  M   25   6  11106
#
# [6039 rows x 5 columns]

# %%
## lading data movie
movie=pd.read_csv("C:/Users/Aishani/Downloads/movies (1).dat",sep='::',engine='python')

# %%
movie
# Out:
#          1                    Toy Story (1995)   Animation|Children's|Comedy
# 0        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1        3             Grumpier Old Men (1995)                Comedy|Romance
# 2        4            Waiting to Exhale (1995)                  Comedy|Drama
# 3        5  Father of the Bride Part II (1995)                        Comedy
# 4        6                         Heat (1995)         Action|Crime|Thriller
# ...    ...                                 ...                           ...
# 3877  3948             Meet the Parents (2000)                        Comedy
# 3878  3949          Requiem for a Dream (2000)                         Drama
# 3879  3950                    Tigerland (2000)                         Drama
# 3880  3951             Two Family House (2000)                         Drama
# 3881  3952               Contender, The (2000)                Drama|Thriller
#
# [3882 rows x 3 columns]

# %%
movie.columns =['MovieIDs','MovieName','Category']
movie.dropna(inplace=True)
movie.head()
# Out:
#    MovieIDs                           MovieName                      Category
# 0         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1         3             Grumpier Old Men (1995)                Comedy|Romance
# 2         4            Waiting to Exhale (1995)                  Comedy|Drama
# 3         5  Father of the Bride Part II (1995)                        Comedy
# 4         6                         Heat (1995)         Action|Crime|Thriller

# %%
rating.columns =['ID','MovieID','Rating','Time-Stamp']
rating.dropna(inplace=True)
rating.head()
# Out:
#    ID  MovieID  Rating  Time-Stamp
# 0   1      661       3   978302109
# 1   1      914       3   978301968
# 2   1     3408       4   978300275
# 3   1     2355       5   978824291
# 4   1     1197       3   978302268

# %%
user.columns =['UserID','Gender','Age','Occupation','Zip-code']
user.dropna(inplace=True)
user.head()
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       2      M   56          16    70072
# 1       3      M   25          15    55117
# 2       4      M   45           7    02460
# 3       5      M   25          20    55455
# 4       6      F   50           9    55117

# %%
df=pd.concat([rating,movie,user],axis=1)
df ## the ultimate data we need
# Out:
#            ID  MovieID  Rating  Time-Stamp  MovieIDs  \
# 0           1      661       3   978302109       2.0
# 1           1      914       3   978301968       3.0
# 2           1     3408       4   978300275       4.0
# 3           1     2355       5   978824291       5.0
# 4           1     1197       3   978302268       6.0
# ...       ...      ...     ...         ...       ...
# 1000203  6040     1091       1   956716541       NaN
# 1000204  6040     1094       5   956704887       NaN
# 1000205  6040      562       5   956704746       NaN
# 1000206  6040     1096       4   956715648       NaN
# 1000207  6040     1097       4   956715569       NaN
#
#                                   MovieName                      Category  \
# 0                            Jumanji (1995)  Adventure|Children's|Fantasy
# 1                   Grumpier Old Men (1995)                Comedy|Romance
# 2                  Waiting to Exhale (1995)                  Comedy|Drama
# ...

# %% [markdown]
# #### visualisig dataset wrt age:

# %%
import seaborn as sns
sns.displot(df,x="Age",bins=8)

# %% [markdown]
# From the visualisation it is clear that,
#
# Between 20-30 age group mostly watches movies.

# %%
## visualization of user's ratings



import matplotlib.pyplot as plt
# %matplotlib inline
df['Rating'].value_counts().plot(kind='bar',alpha=0.7,figsize=(10,10))
plt.show()

# %% [markdown]
# From the visualisation,
# we can see clearly that most of the users have given 4 rating to the movies.

# %%
rating['MovieID']
# Out:
# 0           661
# 1           914
# 2          3408
# 3          2355
# 4          1197
#            ...
# 1000203    1091
# 1000204    1094
# 1000205     562
# 1000206    1096
# 1000207    1097
# Name: MovieID, Length: 1000208, dtype: int64

# %% [markdown]
# ## 5 star rating movies:

# %%
x=df[df['Rating']==5]
x['MovieName'].dropna()
# Out:
# 3       Father of the Bride Part II (1995)
# 5                           Sabrina (1995)
# 6                      Tom and Huck (1995)
# 9           American President, The (1995)
# 13                 Cutthroat Island (1995)
#                        ...
# 3860        Giant Gila Monster, The (1959)
# 3865      Phantom of the Opera, The (1943)
# 3866                        Runaway (1984)
# 3870        Sorority House Massacre (1986)
# 3880               Two Family House (2000)
# Name: MovieName, Length: 840, dtype: object

# %%
df['Age']
# Out:
# 0          56.0
# 1          25.0
# 2          45.0
# 3          25.0
# 4          50.0
#            ...
# 1000203     NaN
# 1000204     NaN
# 1000205     NaN
# 1000206     NaN
# 1000207     NaN
# Name: Age, Length: 1000208, dtype: float64

# %% [markdown]
# ## Movie category :

# %%
df.groupby('Category').size().sort_values(ascending=True)
# Out:
# Category
# Animation|Children's|Fantasy|Musical        1
# Adventure|Animation|Sci-Fi                  1
# Adventure|Animation|Film-Noir               1
# Adventure|Animation|Children's|Sci-Fi       1
# Adventure|Animation|Children's|Fantasy      1
#                                          ...
# Comedy|Romance                            142
# Comedy|Drama                              162
# Horror                                    178
# Comedy                                    521
# Drama                                     843
# Length: 301, dtype: int64

# %% [markdown]
#  The mostly watched category is Drama

# %% [markdown]
# # Importing libraries:

# %%
import numpy as np
import random as rnd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df1=df.dropna()
features = df1[['MovieID','Age']].values ## we have selected oue feature as movieID and Age
labels = df1[['Rating']].values ##response

# %% [markdown]
# ## Training and test split:

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)

# %% [markdown]
# # fitting decision tree classifier to the data:

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)
Y_pred = decision_tree.predict(X_test)
acc_decision_tree = round(decision_tree.score(X_train, y_train) * 100, 2)
acc_decision_tree
print("the accuracy score:",acc_decision_tree)
# Out:
# the accuracy score: 86.53

# %% [markdown]
# Our model is 87% accurate
